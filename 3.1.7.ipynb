# %% [markdown]
# <a href="https://colab.research.google.com/github/rhs329/boostcourse-3-/blob/main/3.1.7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv("/content/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#나이

# %%
# One=Hot-Encoding
df["Age_low"] = df["Age"] < 25
df["Age_middle"] = (df["Age"] >= 25) & (df["Age"] <= 60)
df["Age_high"] = df["Age"] > 60
df[["Age", "Age_low", "Age_middle", "Age_high"]].head()
# Out:
#    Age  Age_low  Age_middle  Age_high
# 0   50    False        True     False
# 1   31    False        True     False
# 2   32    False        True     False
# 3   21     True       False     False
# 4   33    False        True     False

# %%
sns.countplot(data=df, x = "Age_low", hue = "Outcome")
# Out:
# <Axes: xlabel='Age_low', ylabel='count'>

# %%
# 결측치 다루기

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# Age_low                     0
# Age_middle                  0
# Age_high                    0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df["Insulin_nan"] = df["Insulin"].replace(0, np.nan)
df[["Insulin", "Insulin_nan"]].head()
# Out:
#    Insulin  Insulin_nan
# 0        0          NaN
# 1        0          NaN
# 2        0          NaN
# 3       94         94.0
# 4      168        168.0

# %%
df["Insulin_nan"].isnull().sum()
# Out:
# np.int64(374)

# %%
df["Insulin_nan"].isnull().mean()
# Out:
# np.float64(0.4869791666666667)

# %%
df.groupby(["Outcome"])[["Insulin", "Insulin_nan"]].agg(["mean", "median"])
# Out:
#             Insulin        Insulin_nan
#                mean median        mean median
# Outcome
# 0         68.792000   39.0  130.287879  102.5
# 1        100.335821    0.0  206.846154  169.5

# %%
#결측치 세우기
df.loc[(df["Outcome"] == 0) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 102.5
df.loc[(df["Outcome"] == 1) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 169.5

# %%
# 왜도, 첨

# %%
sns.distplot(df.loc[df["Insulin"] > 0, "Insulin"])
# Out:
# /tmp/ipython-input-3999794139.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df["Insulin"] > 0, "Insulin"])
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(np.log(df.loc[df["Insulin"] > 0, "Insulin"] + 1))
# Out:
# /tmp/ipython-input-357358582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df.loc[df["Insulin"] > 0, "Insulin"] + 1))
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(df["Insulin_nan"])
# Out:
# /tmp/ipython-input-391338383.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Insulin_nan"])
# <Axes: xlabel='Insulin_nan', ylabel='Density'>

# %%
df["Insulin_log"] = np.log(df["Insulin_nan"] + 1)
sns.distplot(df["Insulin_log"])
# Out:
# /tmp/ipython-input-557257811.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Insulin_log"])
# <Axes: xlabel='Insulin_log', ylabel='Density'>

# %%
sns.lmplot(data=df, x="Insulin_nan", y="Glucose", hue="Outcome")

# %%
df["low_glu_insulin"] = (df["Glucose"] < 100) & (df["Insulin_nan"] <= 102.5)
df["low_glu_insulin"].head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: low_glu_insulin, dtype: bool

# %%
pd.crosstab(df["Outcome"], df["low_glu_insulin"])
# Out:
# low_glu_insulin  False  True
# Outcome
# 0                  332    168
# 1                  263      5

# %%
# 이상치 다루기

# %%
plt.figure(figsize=(2, 15))
sns.boxplot(df["Insulin_nan"])
# Out:
# <Axes: ylabel='Insulin_nan'>

# %%
df["Insulin_nan"].describe()
# Out:
# count    768.000000
# mean     141.753906
# std       89.100847
# min       14.000000
# 25%      102.500000
# 50%      102.500000
# 75%      169.500000
# max      846.000000
# Name: Insulin_nan, dtype: float64

# %%
IQR3 = df["Insulin_nan"].quantile(0.75)
IQR1 = df["Insulin_nan"].quantile(0.25)
IQR = IQR3 - IQR1
IQR
# Out:
# np.float64(67.0)

# %%
OUT = IQR3 + (IQR * 1.5)
OUT
# Out:
# np.float64(270.0)

# %%
df[df["Insulin_nan"] > OUT].shape
# Out:
# (51, 15)

# %%
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
train = df[:split_count].copy()
train.shape
# Out:
# (614, 15)

# %%
train[train["Insulin_nan"] < 600].shape
# Out:
# (610, 15)

# %%
train = train[train["Insulin_nan"] < 600]
train.shape
# Out:
# (607, 15)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 15)

# %%
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names.remove("Age_low")
feature_names.remove("Age_middle")
feature_names.remove("Age_high")
feature_names.remove("Insulin")
feature_names.remove("Insulin_log")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Insulin_nan',
#  'low_glu_insulin']

# %%
label_name = "Outcome"
label_name
# Out:
# 'Outcome'

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (607, 8)
#    Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  Age  \
# 0      148             72             35  33.6                     0.627   50
# 1       85             66             29  26.6                     0.351   31
# 2      183             64              0  23.3                     0.672   32
# 3       89             66             23  28.1                     0.167   21
# 4      137             40             35  43.1                     2.288   33
#
#    Insulin_nan  low_glu_insulin
# 0        169.5            False
# 1        102.5             True
# 2        169.5            False
# 3         94.0             True
# 4        168.0            False

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (607,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 8)
#      Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  \
# 614      138             74             26  36.1                     0.557
# 615      106             72              0  25.8                     0.207
# 616      117             96              0  28.7                     0.157
# 617       68             62             13  20.1                     0.257
# 618      112             82             24  28.2                     1.282
#
#      Age  Insulin_nan  low_glu_insulin
# 614   50        144.0            False
# 615   27        102.5            False
# 616   30        102.5            False
# 617   23         15.0             True
# 618   50        169.5            False

# %%
y_test = test[label_name]

print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 0, 0, 1])

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=feature_names)
# Out:
# [Text(0.520766129032258, 0.9615384615384616, 'Insulin_nan <= 143.5\ngini = 0.452\nsamples = 607\nvalue = [398, 209]'),
#  Text(0.3064516129032258, 0.8846153846153846, 'Insulin_nan <= 109.0\ngini = 0.163\nsamples = 380\nvalue = [346, 34]'),
#  Text(0.4136088709677419, 0.9230769230769231, 'True  '),
#  Text(0.23225806451612904, 0.8076923076923077, 'BMI <= 49.95\ngini = 0.098\nsamples = 329\nvalue = [312, 17]'),
#  Text(0.21935483870967742, 0.7307692307692307, 'Glucose <= 151.5\ngini = 0.082\nsamples = 326\nvalue = [312, 14]'),
#  Text(0.1870967741935484, 0.6538461538461539, 'Insulin_nan <= 99.5\ngini = 0.062\nsamples = 312\nvalue = [302, 10]'),
#  Text(0.17419354838709677, 0.5769230769230769, 'Insulin_nan <= 95.5\ngini = 0.154\nsamples = 119\nvalue = [109, 10]'),
#  Text(0.16129032258064516, 0.5, 'BloodPressure <= 83.0\ngini = 0.127\nsamples = 117\nvalue = [109, 8]'),
#  Text(0.1032258064516129, 0.4230769230769231, 'DiabetesPedigreeFunction <= 0.677\ngini = 0.088\nsamples = 108\nvalue = [103, 5]'),
#  Text(0.05161290322580645, 0.34615384615384615, 'SkinThickness <= 31.5\ngini = 0.044\nsamples = 89\nvalue = [87, 2]'),
#  Text(0.03870967741935484, 0.2692307692307692, 'gini = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(0.06451612903225806, 0.2692307692307692, 'DiabetesPedigreeFunction <= 0.509\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.03870967741935484, 0.19230769230769232, 'BloodPressure <= 54.0\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.025806451612903226, 0.11538461538461539, 'Insulin_nan <= 85.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.012903225806451613, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03870967741935484, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05161290322580645, 0.11538461538461539, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.09032258064516129, 0.19230769230769232, 'BMI <= 37.05\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0
ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6129032258064516, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6387096774193548, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6516129032258065, 0.6538461538461539, 'gini = 0.0\nsamples = 108\nvalue = [0, 108]'),
#  Text(0.8766129032258064, 0.8076923076923077, 'Glucose <= 154.5\ngini = 0.493\nsamples = 95\nvalue = [42.0, 53.0]'),
#  Text(0.7790322580645161, 0.7307692307692307, 'Age <= 28.5\ngini = 0.48\nsamples = 65\nvalue = [39, 26]'),
#  Text(0.6774193548387096, 0.6538461538461539, 'BloodPressure <= 53.0\ngini = 0.245\nsamples = 28\nvalue = [24, 4]'),
#  Text(0.6645161290322581, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6903225806451613, 0.5769230769230769, 'Age <= 23.5\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.6774193548387096, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.7032258064516129, 0.5, 'Glucose <= 127.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.6903225806451613, 0.4230769230769231, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.7161290322580646, 0.4230769230769231, 'Glucose <= 135.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.7032258064516129, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7290322580645161, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8806451612903226, 0.6538461538461539, 'BloodPressure <= 77.0\ngini = 0.482\nsamples = 37\nvalue = [15, 22]'),
#  Text(0.8387096774193549, 0.5769230769230769, 'DiabetesPedigreeFunction <= 0.737\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.7935483870967742, 0.5, 'Age <= 29.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.7677419354838709, 0.4230769230769231, 'Insulin_nan <= 256.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7548387096774194, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7806451612903226, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8193548387096774, 0.4230769230769231, 'BMI <= 38.55\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.8064516129032258, 0.34615384615384615, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.832258064516129, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8838709677419355, 0.5, 'Insulin_nan <= 199.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.8709677419354839, 0.4230769230769231, 'DiabetesPedigreeFunction <= 1.142\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8580645161290322, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8838709677419355, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.896774193548387, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9225806451612903, 0.5769230769230769, 'SkinThickness <= 20.0\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.9096774193548387, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9354838709677419, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.9741935483870968, 0.7307692307692307, 'BMI <= 45.95\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.9612903225806452, 0.6538461538461539, 'BloodPressure <= 52.0\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.9483870967741935, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9741935483870968, 0.5769230769230769, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.9870967741935484, 0.6538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model, feature_names=feature_names,
                         filled=True,
                         fontsize=10)

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_tree = export_graphviz(model, feature_names = feature_names,
filled=True)
graphviz.Source(dot_tree)

# %%
model.feature_importances_
# Out:
# array([0.09259951, 0.0395152 , 0.04409642, 0.05784192, 0.04025545,
#        0.08899905, 0.63669245, 0.        ])

# %%
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %%
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# np.int64(18)

# %%
y_test == y_predict
# Out:
# 614    True
# 615    True
# 616    True
# 617    True
# 618    True
#        ...
# 763    True
# 764    True
# 765    True
# 766    True
# 767    True
# Name: Outcome, Length: 154, dtype: bool

# %%
abs(y_test - y_predict).sum() / len(y_test)
# Out:
# np.float64(0.11688311688311688)

# %%
# 87이 인슐린의 결측치를 중앙값으로 대체
(len(y_test) - diff_count) / len(y_test) * 100
# Out:
# np.float64(88.31168831168831)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.8831168831168831

# %%
model.score(X_test, y_test) * 100
# Out:
# 88.31168831168831

# %% [markdown]
# <a href="https://colab.research.google.com/github/rhs329/boostcourse-3-/blob/main/3.1.4~3.1.6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv("/content/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#나이

# %%
# One=Hot-Encoding
df["Age_low"] = df["Age"] < 25
df["Age_middle"] = (df["Age"] >= 25) & (df["Age"] <= 60)
df["Age_high"] = df["Age"] > 60
df[["Age", "Age_low", "Age_middle", "Age_high"]].head()
# Out:
#    Age  Age_low  Age_middle  Age_high
# 0   50    False        True     False
# 1   31    False        True     False
# 2   32    False        True     False
# 3   21     True       False     False
# 4   33    False        True     False

# %%
sns.countplot(data=df, x = "Age_low", hue = "Outcome")
# Out:
# <Axes: xlabel='Age_low', ylabel='count'>

# %%
# 결측치 다루기

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# Age_low                     0
# Age_middle                  0
# Age_high                    0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df["Insulin_nan"] = df["Insulin"].replace(0, np.nan)
df[["Insulin", "Insulin_nan"]].head()
# Out:
#    Insulin  Insulin_nan
# 0        0          NaN
# 1        0          NaN
# 2        0          NaN
# 3       94         94.0
# 4      168        168.0

# %%
df["Insulin_nan"].isnull().sum()
# Out:
# np.int64(374)

# %%
df["Insulin_nan"].isnull().mean()
# Out:
# np.float64(0.4869791666666667)

# %%
df.groupby(["Outcome"])[["Insulin", "Insulin_nan"]].agg(["mean", "median"])
# Out:
#             Insulin        Insulin_nan
#                mean median        mean median
# Outcome
# 0         68.792000   39.0  130.287879  102.5
# 1        100.335821    0.0  206.846154  169.5

# %%
#결측치 세우기
df.loc[(df["Outcome"] == 0) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 102.5
df.loc[(df["Outcome"] == 1) & (df["Insulin_nan"].isnull()), "Insulin_nan"] = 169.5

# %%
# 왜도, 첨

# %%
sns.distplot(df.loc[df["Insulin"] > 0, "Insulin"])
# Out:
# /tmp/ipython-input-3999794139.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[df["Insulin"] > 0, "Insulin"])
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(np.log(df.loc[df["Insulin"] > 0, "Insulin"] + 1))
# Out:
# /tmp/ipython-input-357358582.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df.loc[df["Insulin"] > 0, "Insulin"] + 1))
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.distplot(df["Insulin_nan"])
# Out:
# /tmp/ipython-input-391338383.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Insulin_nan"])
# <Axes: xlabel='Insulin_nan', ylabel='Density'>

# %%
df["Insulin_log"] = np.log(df["Insulin_nan"] + 1)
sns.distplot(df["Insulin_log"])
# Out:
# /tmp/ipython-input-557257811.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Insulin_log"])
# <Axes: xlabel='Insulin_log', ylabel='Density'>

# %%
sns.lmplot(data=df, x="Insulin_nan", y="Glucose", hue="Outcome")

# %%
df["low_glu_insulin"] = (df["Glucose"] < 100) & (df["Insulin_nan"] <= 102.5)
df["low_glu_insulin"].head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: low_glu_insulin, dtype: bool

# %%
pd.crosstab(df["Outcome"], df["low_glu_insulin"])
# Out:
# low_glu_insulin  False  True
# Outcome
# 0                  332    168
# 1                  263      5

# %%
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
train = df[:split_count].copy()
train.shape
# Out:
# (614, 15)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 15)

# %%
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names.remove("Age_low")
feature_names.remove("Age_middle")
feature_names.remove("Age_high")
feature_names.remove("Insulin")
feature_names.remove("Insulin_nan")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Insulin_log',
#  'low_glu_insulin']

# %%
label_name = "Outcome"
label_name
# Out:
# 'Outcome'

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  Age  \
# 0      148             72             35  33.6                     0.627   50
# 1       85             66             29  26.6                     0.351   31
# 2      183             64              0  23.3                     0.672   32
# 3       89             66             23  28.1                     0.167   21
# 4      137             40             35  43.1                     2.288   33
#
#    Insulin_log  low_glu_insulin
# 0     5.138735            False
# 1     4.639572             True
# 2     5.138735            False
# 3     4.553877             True
# 4     5.129899            False

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (614,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 8)
#      Glucose  BloodPressure  SkinThickness   BMI  DiabetesPedigreeFunction  \
# 614      138             74             26  36.1                     0.557
# 615      106             72              0  25.8                     0.207
# 616      117             96              0  28.7                     0.157
# 617       68             62             13  20.1                     0.257
# 618      112             82             24  28.2                     1.282
#
#      Age  Insulin_log  low_glu_insulin
# 614   50     4.976734            False
# 615   27     4.639572            False
# 616   30     4.639572            False
# 617   23     2.772589             True
# 618   50     5.138735            False

# %%
y_test = test[label_name]

print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 0, 0, 1])

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=feature_names)
# Out:
# [Text(0.5431338028169014, 0.9615384615384616, 'Insulin_log <= 4.973\ngini = 0.453\nsamples = 614\nvalue = [401, 213]'),
#  Text(0.3345070422535211, 0.8846153846153846, 'Insulin_log <= 4.7\ngini = 0.163\nsamples = 380\nvalue = [346, 34]'),
#  Text(0.43882042253521125, 0.9230769230769231, 'True  '),
#  Text(0.2535211267605634, 0.8076923076923077, 'BMI <= 49.95\ngini = 0.098\nsamples = 329\nvalue = [312, 17]'),
#  Text(0.23943661971830985, 0.7307692307692307, 'Glucose <= 151.5\ngini = 0.082\nsamples = 326\nvalue = [312, 14]'),
#  Text(0.20422535211267606, 0.6538461538461539, 'Insulin_log <= 4.61\ngini = 0.062\nsamples = 312\nvalue = [302, 10]'),
#  Text(0.19014084507042253, 0.5769230769230769, 'Insulin_log <= 4.57\ngini = 0.154\nsamples = 119\nvalue = [109, 10]'),
#  Text(0.176056338028169, 0.5, 'BloodPressure <= 83.0\ngini = 0.127\nsamples = 117\nvalue = [109, 8]'),
#  Text(0.11267605633802817, 0.4230769230769231, 'DiabetesPedigreeFunction <= 0.677\ngini = 0.088\nsamples = 108\nvalue = [103, 5]'),
#  Text(0.056338028169014086, 0.34615384615384615, 'SkinThickness <= 31.5\ngini = 0.044\nsamples = 89\nvalue = [87, 2]'),
#  Text(0.04225352112676056, 0.2692307692307692, 'gini = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(0.07042253521126761, 0.2692307692307692, 'DiabetesPedigreeFunction <= 0.509\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.04225352112676056, 0.19230769230769232, 'BloodPressure <= 54.0\ngini = 0.087\nsamples = 22\nvalue = [21, 1]'),
#  Text(0.028169014084507043, 0.11538461538461539, 'BMI <= 33.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.014084507042253521, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04225352112676056, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.056338028169014086, 0.11538461538461539, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.09859154929577464, 0.19230769230769232, 'BloodPressure <= 67.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08450704225352113, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11267605633802817, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16901408450704225, 0.34615384615384615, 'SkinThickness <= 13.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.15492957746478872, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18309859154929578, 0.2692307692307692, 'Insulin_log <= 4.505\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.15492957746478872, 0.19230769230769232, 'BMI <= 35.95\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.14084507042253522, 0.11538461538461539, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.16901408450704225, 0.11538461538461539, 'low_glu_insulin <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.15492957746478872, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18309859154929578, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2112676056338028, 0.19230769230769232, 'BloodPressure <= 65.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19718309859154928, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22535211267605634, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23943661971830985, 0.4230769230769231, 'SkinThickness <= 40.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.22535211267605634, 0.34615384615384615, 'BloodPressure <= 85.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.2112676056338028, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23943661971830985, 0.2692307692307692, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.2535211267605634, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20422535211267606, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21830985915492956, 0.5769230769230769, 'gini = 0.0\nsamples = 193\nvalue = [193, 0]'),
#  Text(0.2746478873239437, 0.6538461538461539, 'Age <= 36.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(0.24647887323943662, 0.5769230769230769, 'BloodPressure <= 67.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2323943661971831, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2605633802816901, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3028169014084507, 0.5769230769230769, 'Insulin_log <= 3.81\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.2887323943661972, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31690140845070425, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.2676056338028169, 0.7307692307692307, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4154929577464789, 0.8076923076923077, 'Glucose <= 124.5\ngini = 0.444\nsamples = 51\nvalue = [34, 17]'),
#  Text(0.3591549295774648, 0.7307692307692307, 'SkinThickness <= 35.5\ngini = 0.219\nsamples = 24\nvalue = [21, 3]'),
#  Text(0.34507042253521125, 0.6538461538461539, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.3732394366197183, 0.6538461538461539, 'Insulin_log <= 4.908\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3591549295774648, 0.5769230769230769, 'BloodPressure <= 87.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.34507042253521125, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3732394366197183, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3873239436619718, 0.5769230769230769, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.47183098591549294, 0.7307692307692307, 'BMI <= 31.0\ngini = 0.499\nsamples = 27\nvalue = [13, 14]'),
#  Text(0.4295774647887324, 0.6538461538461539, 'DiabetesPedigreeFunction <= 0.22\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.4154929577464789, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44366197183098594, 0.5769230769230769, 'DiabetesPedigreeFunction <= 0.922\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.4295774647887324, 0.5, 'Glucose <= 153.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.4154929577464789, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.44366197183098594, 0.4230769230769231, 'SkinThickness <= 19.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4295774647887324, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45774647887323944, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45774647887323944, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5140845070422535, 0.6538461538461539, 'Age <= 40.0\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.5, 0.5769230769230769, 'Age <= 26.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.4859154929577465, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5140845070422535, 0.5, 'SkinThickness <= 41.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.5, 0.4230769230769231, 'SkinThickness <= 25.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4859154929577465, 0.34615384615384615, 'Insulin_log <= 4.912\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.47183098591549294, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5140845070422535, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.528169014084507, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.528169014084507, 0.5769230769230769, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7517605633802817, 0.8846153846153846, 'Insulin_log <= 5.14\ngini = 0.36\nsamples = 234\nvalue = [55, 179]'),
#  Text(0.6474471830985915, 0.9230769230769231, '  False'),
#  Text(0.647887323943662, 0.8076923076923077, 'Insulin_log <= 5.121\ngini = 0.14\nsamples = 132\nvalue = [10, 122]'),
#  Text(0.5985915492957746, 0.7307692307692307, 'Age <= 29.0\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.5704225352112676, 0.6538461538461539, 'Glucose <= 138.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.5563380281690141, 0.5769230769230769, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5845070422535211, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6267605633802817, 0.6538461538461539, 'SkinThickness <= 16.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.6126760563380281, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6408450704225352, 0.5769230769230769, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6971830985915493, 0.7307692307692307, 'DiabetesPedigreeFunction <= 0.126\ngini = 0.018\nsamples = 111\nvalue = [1, 110]'),
#  Text(0.6830985915492958, 0.6538461538461539, 'Insulin_log <= 5.134\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6690140845070423, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6971830985915493, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7112676056338029, 0.6538461538461539, 'gini = 0.0\nsamples = 108\nvalue = [0, 108]'),
#  Text(0.8556338028169014, 0.8076923076923077, 'Age <= 27.5\ngini = 0.493\nsamples = 102\nvalue = [45, 57]'),
#  Text(0.7676056338028169, 0.7307692307692307, 'Glucose <= 169.0\ngini = 0.382\nsamples = 35\nvalue = [26, 9]'),
#  Text(0.7394366197183099, 0.6538461538461539, 'BloodPressure <= 53.0\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.7253521126760564, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7535211267605634, 0.5769230769230769, 'Age <= 23.5\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.7394366197183099, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.7676056338028169, 0.5, 'Glucose <= 127.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.7535211267605634, 0.4230769230769231, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7816901408450704, 0.4230769230769231, 'Glucose <= 135.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.7676056338028169, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.795774647887324, 0.34615384615384615, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.795774647887324, 0.6538461538461539, 'BMI <= 28.95\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7816901408450704, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8098591549295775, 0.5769230769230769, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9436619718309859, 0.7307692307692307, 'Glucose <= 156.5\ngini = 0.406\nsamples = 67\nvalue = [19, 48]'),
#  Text(0.9154929577464789, 0.6538461538461539, 'BMI <= 38.95\ngini = 0.485\nsamples = 41\nvalue = [17, 24]'),
#  Text(0.9014084507042254, 0.5769230769230769, 'DiabetesPedigreeFunction <= 0.857\ngini = 0.498\nsamples = 32\nvalue = [17, 15]'),
#  Text(0.8661971830985915, 0.5, 'BloodPressure <= 75.0\ngini = 0.461\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.8380281690140845, 0.4230769230769231, 'Glucose <= 145.0\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.823943661971831, 0.34615384615384615, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.852112676056338, 0.34615384615384615, 'BMI <= 34.35\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.8380281690140845, 0.2692307692307692, 'DiabetesPedigreeFunction <= 0.691\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.823943661971831, 0.19230769230769232, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.852112676056338, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8661971830985915, 0.2692307692307692, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8943661971830986, 0.4230769230769231, 'Glucose <= 117.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.8802816901408451, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9084507042253521, 0.34615384615384615, 'Age <= 43.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.8943661971830986, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9225352112676056, 0.2692307692307692, 'Age <= 59.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9084507042253521, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9366197183098591, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9366197183098591, 0.5, 'BMI <= 25.55\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.9225352112676056, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9507042253521126, 0.4230769230769231, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9295774647887324, 0.5769230769230769, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.971830985915493, 0.6538461538461539, 'DiabetesPedigreeFunction <= 1.097\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.9577464788732394, 0.5769230769230769, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.9859154929577465, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model, feature_names=feature_names,
                         filled=True,
                         fontsize=10)

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_tree = export_graphviz(model, feature_names = feature_names,
filled=True)
graphviz.Source(dot_tree)

# %%
model.feature_importances_
# Out:
# array([0.09058029, 0.04355717, 0.03787725, 0.06616874, 0.04479181,
#        0.09422092, 0.61801142, 0.0047924 ])

# %%
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %%
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# np.int64(18)

# %%
y_test == y_predict
# Out:
# 614     True
# 615     True
# 616     True
# 617     True
# 618     True
#        ...
# 763    False
# 764     True
# 765     True
# 766     True
# 767     True
# Name: Outcome, Length: 154, dtype: bool

# %%
abs(y_test - y_predict).sum() / len(y_test)
# Out:
# np.float64(0.11688311688311688)

# %%
# 87이 인슐린의 결측치를 중앙값으로 대
(len(y_test) - diff_count) / len(y_test) * 100
# Out:
# np.float64(88.31168831168831)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.8831168831168831

# %%
model.score(X_test, y_test) * 100
# Out:
# 88.31168831168831

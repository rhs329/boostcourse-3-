# %% [markdown]
# <a href="https://colab.research.google.com/github/rhs329/boostcourse-3-/blob/main/3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv("/content/diabetes.csv")
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#수치형 변수를 범주형 변수로 [3 강의 내용 시작]

# %%
df["Pregnancies_high"] = df["Pregnancies"] > 6
df[["Pregnancies", "Pregnancies_high"]].head()
# Out:
#    Pregnancies  Pregnancies_high
# 0            6             False
# 1            1             False
# 2            8              True
# 3            1             False
# 4            0             False

# %%
#학습 예측 데이터셋 만들기

# %%
feature_names = train.columns.tolist()
feature_names.remove("Pregnancies")
feature_names.remove("Outcome")
feature_names
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Pregnancies_high']

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Pregnancies_high
# 0                     0.627   50             False
# 1                     0.351   31             False
# 2                     0.672   32              True
# 3                     0.167   21             False
# 4                     2.288   33             False

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Pregnancies_high
# 0                     0.627   50             False
# 1                     0.351   31             False
# 2                     0.672   32              True
# 3                     0.167   21             False
# 4                     2.288   33             False

# %%
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 614

# %%
train = df[:split_count].copy()
train.shape
# Out:
# (614, 10)

# %%
test = df[split_count:].copy()
test.shape
# Out:
# (154, 10)

# %%
feature_names = train.columns[:-1].tolist()
feature_names
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
label_name = train.columns[-1]
label_name
# Out:
# 'Outcome'

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (614, 8)
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Pregnancies_high
# 0                     0.627   50             False
# 1                     0.351   31             False
# 2                     0.672   32              True
# 3                     0.167   21             False
# 4                     2.288   33             False

# %%
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (614,)
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (154, 8)
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 614      138             74             26      144  36.1
# 615      106             72              0        0  25.8
# 616      117             96              0        0  28.7
# 617       68             62             13       15  20.1
# 618      112             82             24        0  28.2
#
#      DiabetesPedigreeFunction  Age  Pregnancies_high
# 614                     0.557   50              True
# 615                     0.207   27             False
# 616                     0.157   30             False
# 617                     0.257   23             False
# 618                     1.282   50              True

# %%
y_test = test[label_name]
print(y_test.shape)
y_test.head()
# Out:
# (154,)
# 614    1
# 615    0
# 616    0
# 617    0
# 618    1
# Name: Outcome, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array([1, 0, 1, 0, 1])

# %%
from sklearn.tree import plot_tree

plot_tree(model, feature_names=feature_names)
# Out:
# [Text(0.5698384405339806, 0.9705882352941176, 'Glucose <= 154.5\ngini = 0.453\nsamples = 614\nvalue = [401, 213]'),
#  Text(0.19004095873786409, 0.9117647058823529, 'BMI <= 26.35\ngini = 0.385\nsamples = 518\nvalue = [383, 135]'),
#  Text(0.37993969963592233, 0.9411764705882353, 'True  '),
#  Text(0.038834951456310676, 0.8529411764705882, 'Glucose <= 124.5\ngini = 0.061\nsamples = 128\nvalue = [124, 4]'),
#  Text(0.019417475728155338, 0.7941176470588235, 'DiabetesPedigreeFunction <= 0.675\ngini = 0.019\nsamples = 105\nvalue = [104, 1]'),
#  Text(0.009708737864077669, 0.7352941176470589, 'gini = 0.0\nsamples = 87\nvalue = [87, 0]'),
#  Text(0.02912621359223301, 0.7352941176470589, 'DiabetesPedigreeFunction <= 0.705\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.019417475728155338, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.038834951456310676, 0.6764705882352942, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
# ...

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
tree = plot_tree(model, feature_names=feature_names,
                         filled=True,
                         fontsize=10)

# %%
import graphviz
from sklearn.tree import export_graphviz

dot_tree = export_graphviz(model, feature_names = feature_names,
filled=True)
graphviz.Source(dot_tree)

# %%
#피처의 중요도
model.feature_importances_
# Out:
# array([0.36113225, 0.13903603, 0.04771871, 0.05169699, 0.16935032,
#        0.11242328, 0.11864242, 0.        ])

# %%
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %%
diff_count = abs(y_test - y_predict).sum()
diff_count
# Out:
# np.int64(34)

# %%
(len(y_test) - diff_count) / len(y_test)*100
# Out:
# np.float64(77.92207792207793)

# %%
y_test == y_predict
# Out:
# 614     True
# 615     True
# 616    False
# 617     True
# 618     True
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Name: Outcome, Length: 154, dtype: bool

# %%
abs(y_test - y_predict).sum() / len(y_test)
# Out:
# np.float64(0.2792207792207792)

# %%
(len(y_test) - diff_count) / len(y_test) * 100
# Out:
# np.float64(72.07792207792207)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.7207792207792207

# %%
model.score(X_test, y_test) * 100
# Out:
# 72.07792207792207
